# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Exercise 1: Plotting and Analytical Function

# %%
x = np.linspace(-50, 50, 100)
y = np.power(x, 2)

# %%
x[0:5], y[0:5]
# Out:
# (array([-50.        , -48.98989899, -47.97979798, -46.96969697,
#         -45.95959596]),
#  array([2500.        , 2400.01020304, 2302.06101418, 2206.15243343,
#         2112.28446077]))

# %%
plt.plot(x,y)

# %%
yhat = np.power(x, 3)
plt.plot(x, yhat)

# %% [markdown]
# ## Exercise 2: Creating a Graph

# %%
fig, ax = plt.subplots()
x = np.linspace(0,100,500)
y = np.sin(2*np.pi*x/100)
ax.plot(x, y)

# %% [markdown]
# # Exercise 3: Graph for a Mathematical Function

# %%
x = np.linspace(0,100,200)
y = np.sin(x)

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# # Exercise 4: Line graph using different Libraries

# %%
X = np.arange(0,100)
Y = np.random.randint(0, 200, size=X.shape[0])

# %%
plt.plot(X, Y)

# %%
df = pd.DataFrame({'X':X, 'Y':Y})
df
# Out:
#      X    Y
# 0    0  173
# 1    1  122
# 2    2   12
# 3    3   84
# 4    4   26
# ..  ..  ...
# 95  95  131
# 96  96   11
# 97  97  189
# 98  98   61
# 99  99  152
#
# [100 rows x 2 columns]

# %%
df.plot('X','Y')
# Out:
# <Axes: xlabel='X'>

# %%
sns.lineplot(data=df, x='X', y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %% [markdown]
# # Exercise 5: Histogram of Horsepower Distribution

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
df = pd.read_csv(url)
df.head()
# Out:
#   18.0   8   307.0      130.0      3504.      12.0   70  1\t"chevrolet chevelle malibu"
# 0  15.0   8   350.0      165.0      3693.      11...
# 1  18.0   8   318.0      150.0      3436.      11...
# 2  16.0   8   304.0      150.0      3433.      12...
# 3  17.0   8   302.0      140.0      3449.      10...
# 4  15.0   8   429.0      198.0      4341.      10...

# %%
column_names = ['mpg', 'Cylinders', 'displacement', 'horsepower', 'weight',
                'acceleration', 'year', 'origin', 'name']

# %%
df = pd.read_csv(url, names = column_names, delim_whitespace=True)
df.head()
# Out:
#     mpg  Cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.horsepower.unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', nan, '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
df.loc[df.horsepower == '?', 'horsepower'] = np.nan

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'])

# %%
df['full_date'] = pd.to_datetime(df.year, format='%y')

# %%
df['year'] = df['full_date'].dt.year

# %%
df.head()
# Out:
#     mpg  Cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0  3504.0          12.0  1970
# 1  15.0          8         350.0       165.0  3693.0          11.5  1970
# 2  18.0          8         318.0       150.0  3436.0          11.0  1970
# 3  16.0          8         304.0       150.0  3433.0          12.0  1970
# 4  17.0          8         302.0       140.0  3449.0          10.5  1970
#
#    origin                       name  full_date
# 0       1  chevrolet chevelle malibu 1970-01-01
# 1       1          buick skylark 320 1970-01-01
# 2       1         plymouth satellite 1970-01-01
# 3       1              amc rebel sst 1970-01-01
# 4       1                ford torino 1970-01-01

# %%
df.horsepower.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(x=df['weight'])
plt.show()
# Out:
# /tmp/ipykernel_312048/4054686091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['weight'])

# %% [markdown]
# # Exercise 6: Analyze the behavior of the Number of Cylinders and Horsepower using a Boxplot

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 
                'weight', 'acceleration', 'year', 'origin', 'name']

# %%
df = pd.read_csv(url, names= column_names, delim_whitespace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['full_date'] = pd.to_datetime(df.year, format='%y')
df['year'] = df['full_date'].dt.year

# %%
sns.boxplot(data=df, x="cylinders", y="horsepower")
# Out:
# <Axes: xlabel='cylinders', ylabel='horsepower'>

# %%
df.boxplot(column='horsepower', by='cylinders')
# Out:
# <Axes: title={'center': 'horsepower'}, xlabel='cylinders'>

# %% [markdown]
# ## Visualization

# %%
fig, ax = plt.subplots()
ax.scatter(x=df['horsepower'], y=df['weight'])

# %%
sns.scatterplot(data=df, x='horsepower', y='weight', 
                hue='cylinders', size='mpg')
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
df.plot(kind='scatter', x='horsepower', y='weight')
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
fig, ax = plt.subplots()
df.plot(kind='scatter', x='horsepower', y='weight', ax=ax)
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
df.groupby('year')['horsepower'].mean()
# Out:
# year
# 1970    147.827586
# 1971    107.037037
# 1972    120.178571
# 1973    130.475000
# 1974     94.230769
# 1975    101.066667
# 1976    101.117647
# 1977    105.071429
# 1978     99.694444
# 1979    101.206897
# 1980     77.481481
# 1981     81.035714
# 1982     81.466667
# Name: horsepower, dtype: float64

# %%
df.groupby('year')['horsepower'].mean() \
    .plot(ls='-.', color='r', lw=3)
# Out:
# <Axes: xlabel='year'>

# %%
df.plot(kind='scatter', x='weight', y='horsepower', figsize=(10,5))
# Out:
# <Axes: xlabel='weight', ylabel='horsepower'>

# %%
df.plot(kind='scatter', x='weight', y='horsepower', figsize=(10,5))
plt.savefig('horsepower_weight_scatter.png')

# %%
df.plot(kind='scatter', x='weight', y='horsepower', figsize=(10,5))
plt.savefig('horsepower_weight_scatter.png')

# %%
sns_scatter = sns.scatterplot(data=df, x='horsepower', y='weight',
                              hue='cylinders', size='mpg')
plt.savefig('scatter_fig.png', dpi=300)
